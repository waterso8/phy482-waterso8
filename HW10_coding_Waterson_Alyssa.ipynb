# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import numpy as np

# %%
t = 1e-15
k0 = 1
sigma = 1
c = 3e8
x = np.linspace(0,1,100)
f0 = np.cos((x-c*t)**2 * sigma**2 * (1/2))
plt.plot(x,f0)

# %% [markdown]
# So uhhhhhhhhhhhhhhhhhhhhhhhhhhh here's what I got, sorry it's not time dependent, uhhh it looks pretty cool though. SO thanks!
